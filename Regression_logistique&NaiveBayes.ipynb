# %%
import pandas

# %% [markdown]
# # 1-LECTURE DES DONNées

# %%
data=pandas.read_csv("train_v2.csv",skipinitialspace=True)
data.head(10)
# Out:
#   country  year     uniqueid bank_account location_type cellphone_access  \
# 0   Kenya  2018   uniqueid_1          Yes         Rural              Yes
# 1   Kenya  2018   uniqueid_2           No         Rural               No
# 2   Kenya  2018   uniqueid_3          Yes         Urban              Yes
# 3   Kenya  2018   uniqueid_4           No         Rural              Yes
# 4   Kenya  2018   uniqueid_5           No         Urban               No
# 5   Kenya  2018   uniqueid_6           No         Rural               No
# 6   Kenya  2018   uniqueid_7           No         Rural              Yes
# 7   Kenya  2018   uniqueid_8           No         Rural              Yes
# 8   Kenya  2018   uniqueid_9          Yes         Rural              Yes
# 9   Kenya  2018  uniqueid_10           No         Urban              Yes
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
# 5               7                 26               Female
# 6               7                 32               Female
# 7               1                 42               Female
# 8               3                 54                 Male
# 9               3                 76               Female
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# 2         Other relative     Single/Never Married
# 3      Head of Household  Married/Living together
# 4                  Child     Single/Never Married
# 5                 Spouse  Married/Living together
# 6                 Spouse  Married/Living together
# 7      Head of Household  Married/Living together
# 8      Head of Household  Married/Living together
# 9      Head of Household       Divorced/Seperated
#
#                    education_level                      job_type
# 0              Secondary education                 Self employed
# 1              No formal education          Government Dependent
# 2  Vocational/Specialised training                 Self employed
# 3                Primary education     Formally employed Private
# 4                Primary education           Informally employed
# 5                Primary education           Informally employed
# 6                Primary education                 Self employed
# 7               Tertiary education  Formally employed Government
# 8              Secondary education           Farming and Fishing
# 9              No formal education          Remittance Dependent

# %% [markdown]
# # 2-Traitement des variables qualitatives:

# %%
#get the cols correspondantes
corr=(data.dtypes =='object')
qual_cols=list(corr[corr].index)
del qual_cols[1]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
data_1=data.copy()
for col in qual_cols:
    data_1[col]=label_encoder.fit_transform(data[col])

# %%
data_1.pop("uniqueid")
# Out:
# 0           uniqueid_1
# 1           uniqueid_2
# 2           uniqueid_3
# 3           uniqueid_4
# 4           uniqueid_5
#              ...
# 23519    uniqueid_2113
# 23520    uniqueid_2114
# 23521    uniqueid_2115
# 23522    uniqueid_2116
# 23523    uniqueid_2117
# Name: uniqueid, Length: 23524, dtype: object

# %%
data_1
# Out:
#        country  year  bank_account  location_type  cellphone_access  \
# 0            0  2018             1              0                 1
# 1            0  2018             0              0                 0
# 2            0  2018             1              1                 1
# 3            0  2018             0              0                 1
# 4            0  2018             0              1                 0
# ...        ...   ...           ...            ...               ...
# 23519        3  2018             0              0                 1
# 23520        3  2018             0              0                 1
# 23521        3  2018             0              0                 1
# 23522        3  2018             0              1                 1
# 23523        3  2018             0              0                 1
#
#        household_size  age_of_respondent  gender_of_respondent  \
# 0                   3                 24                     0
# 1                   5                 70                     0
# 2                   5                 26                     1
# 3                   5                 34                     0
# 4                   8                 26                     1
# ...               ...                ...                   ...
# 23519               4                 48                     0
# 23520               2                 27                     0
# 23521               5                 27                     0
# 23522               7                 30                     0
# 23523              10                 20                     1
#
#        relationship_with_head  marital_status  education_level  job_type
# 0                           5               2                3         9
# 1                           1               4                0         4
# 2                           3               3                5         9
# 3                           1               2                2         3
# 4                           0               3                2         5
# ...                       ...             ...              ...       ...
# 23519                       1               0                0         7
# 23520                       1               3                3         7
# 23521                       4               4                2         7
# 23522                       4               0                3         9
# 23523                       0               3                3         6
#
# [23524 rows x 12 columns]

# %%
Y = data_1.pop("bank_account")
X_train = data_1
Y_train =Y

# %%
from sklearn.linear_model import LogisticRegression
logisticmodel = LogisticRegression()
logisticmodel.fit(X_train, Y_train)
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %% [markdown]
# # Lecture du fichier test

# %%
data_test=pandas.read_csv("test_v2.csv",skipinitialspace=True)
data_test.head(10)
# Out:
#   country  year       uniqueid location_type cellphone_access  household_size  \
# 0   Kenya  2018  uniqueid_6056         Urban              Yes               3
# 1   Kenya  2018  uniqueid_6060         Urban              Yes               7
# 2   Kenya  2018  uniqueid_6065         Rural               No               3
# 3   Kenya  2018  uniqueid_6072         Rural               No               6
# 4   Kenya  2018  uniqueid_6073         Urban               No               3
# 5   Kenya  2018  uniqueid_6074         Rural              Yes               4
# 6   Kenya  2018  uniqueid_6075         Rural              Yes               4
# 7   Kenya  2018  uniqueid_6076         Urban              Yes               3
# 8   Kenya  2018  uniqueid_6077         Rural              Yes               4
# 9   Kenya  2018  uniqueid_6078         Urban              Yes               1
#
#    age_of_respondent gender_of_respondent relationship_with_head  \
# 0                 30                 Male      Head of Household
# 1                 51                 Male      Head of Household
# 2                 77               Female                 Parent
# 3                 39               Female      Head of Household
# 4                 16                 Male                  Child
# 5                 25               Female                 Spouse
# 6                 32               Female      Head of Household
# 7                 24               Female                 Spouse
# 8                 22               Female                  Child
# 9                 42                 Male      Head of Household
#
#             marital_status                  education_level  \
# 0  Married/Living together              Secondary education
# 1  Married/Living together  Vocational/Specialised training
# 2  Married/Living together              No formal education
# 3  Married/Living together                Primary education
# 4     Single/Never Married              Secondary education
# 5  Married/Living together                Primary education
# 6       Divorced/Seperated                Primary education
# 7  Married/Living together  Vocational/Specialised training
# 8     Single/Never Married                Primary education
# 9       Divorced/Seperated              Secondary education
#
#                        job_type
# 0  Formally employed Government
# 1     Formally employed Private
# 2          Remittance Dependent
# 3          Remittance Dependent
# 4          Remittance Dependent
# 5                 Self employed
# 6           Informally employed
# 7                 Self employed
# 8           Informally employed
# 9           Farming and Fishing

# %%
#get the cols correspondantes
corr=(data_test.dtypes =='object')
qual_cols=list(corr[corr].index)
del qual_cols[1]
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
data_1_test=data_test.copy()

for col in qual_cols:
    data_1_test[col]=label_encoder.fit_transform(data_test[col])
data_1_test.pop("uniqueid")
# Out:
# 0        uniqueid_6056
# 1        uniqueid_6060
# 2        uniqueid_6065
# 3        uniqueid_6072
# 4        uniqueid_6073
#              ...
# 10081    uniqueid_2998
# 10082    uniqueid_2999
# 10083    uniqueid_3000
# 10084    uniqueid_3001
# 10085    uniqueid_3002
# Name: uniqueid, Length: 10086, dtype: object

# %%
Predictions = logisticmodel.predict(data_1_test)

# %%
Predictions
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %% [markdown]
# Evaluation

# %%
from sklearn.model_selection import cross_val_score
accuracy= cross_val_score(logisticmodel, X_train, Y_train, scoring='accuracy', cv = 10)
print((1-accuracy).mean())
# Out:
# C:\Users\pc\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\pc\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\pc\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\pc\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\pc\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\pc\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\pc\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\pc\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\pc\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\pc\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.13088367462533018

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
NBmod = GaussianNB()

# %%
NBmod.fit(X_train,Y_train)

from sklearn.model_selection import cross_val_score
accuracy= cross_val_score(NBmod, X_train, Y_train, scoring='accuracy', cv = 10)
print((1-accuracy).mean())
# Out:
# 0.19074436911553067
